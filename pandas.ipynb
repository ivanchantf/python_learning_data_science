# %% [markdown]
# # Create DataFrame

# %%
import pandas as pd
pd.DataFrame({'Name':['Peter','John','Mary'],"Salary":['30000','40000','50000']})
# Out:
#     Name Salary
# 0  Peter  30000
# 1   John  40000
# 2   Mary  50000

# %% [markdown]
# # Create Series

# %%
series= pd.Series(['1 cup','2 cup','3 cup'],index=['Milk','Juice','Coffee'],name='Drink')
print(series)
# Out:
# Milk      1 cup
# Juice     2 cup
# Coffee    3 cup
# Name: Drink, dtype: object

# %% [markdown]
# # Read From csv

# %%
wine=pd.read_csv('wine.csv') #provide index_col if index provided in csv
wine
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %% [markdown]
# # Write to csv

# %%
series.to_csv('drink.csv')

# %% [markdown]
# # Selecting

# %% [markdown]
# loc is inclusive range <br>
# iloc is exclusive range

# %%
wine.loc[0:9,'Alcohol'] #first ten row , only 'Alcohol' col
# Out:
# 0    14.23
# 1    13.20
# 2    13.16
# 3    14.37
# 4    13.24
# 5    14.20
# 6    14.39
# 7    14.06
# 8    14.83
# 9    13.86
# Name: Alcohol, dtype: float64

# %%
wine.iloc[0:10,1] #first ten row , only 'Alcohol' col
# Out:
# 0    14.23
# 1    13.20
# 2    13.16
# 3    14.37
# 4    13.24
# 5    14.20
# 6    14.39
# 7    14.06
# 8    14.83
# 9    13.86
# Name: Alcohol, dtype: float64

# %%
wine.loc[[1,3,4],['Alcohol','Mg']] #row with idx 1-3-4 , 'Alcohol' 'Mg' cols
# Out:
#    Alcohol   Mg
# 1    13.20  100
# 3    14.37  113
# 4    13.24  118

# %%
wine.loc[(wine.Mg>100) & (wine.Alcohol>13) ]
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# 5       1    14.20        1.76  2.45  15.2  112     3.27        3.39
# 7       1    14.06        2.15  2.61  17.6  121     2.60        2.51
# 10      1    14.10        2.16  2.30  18.0  105     2.95        3.32
# 14      1    14.38        1.87  2.38  12.0  102     3.30        3.64
# 15      1    13.63        1.81  2.70  17.2  112     2.85        2.91
# 16      1    14.30        1.92  2.72  20.0  120     2.80        3.14
# 17      1    13.83        1.57  2.62  20.0  115     2.95        3.40
# 18      1    14.19        1.59  2.48  16.5  108     3.30        3.93
# 19      1    13.64        3.10  2.56  15.2  116     2.70        3.03
# ...

# %%
flight = pd.read_csv('airlines_flights_data.csv',index_col=0)
print(flight)
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# index
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# index
# ...

# %%
flight.loc[flight.airline.isin(['SpiceJet','AirAsia'])]
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# index
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 18       AirAsia   I5-747       Delhi        Evening   one  Early_Morning
# 19       AirAsia   I5-747       Delhi        Evening   one        Morning
# ...          ...      ...         ...            ...   ...            ...
# 206538   AirAsia  I5-1229     Chennai          Night   one        Morning
# 206539   AirAsia  I5-2462     Chennai          Night   one        Morning
# 206591   AirAsia   I5-517     Chennai        Morning  zero        Morning
# 206616   AirAsia  I5-1229     Chennai          Night   one        Morning
# 206617   AirAsia  I5-2462     Chennai          Night   one        Morning
#
#        destination_city    class  duration  days_left  price
# index
# ...

# %%
flight.loc[flight.airline.isnull()]
# Out:
# Empty DataFrame
# Columns: [airline, flight, source_city, departure_time, stops, arrival_time, destination_city, class, duration, days_left, price]
# Index: []

# %% [markdown]
# # Summary function and mapping

# %%
wine.describe()
# Out:
#              Wine     Alcohol  Malic.acid         Ash         Acl          Mg  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoid.phenols     Proanth   Color.int  \
# count  178.000000  178.000000            178.000000  178.000000  178.000000
# mean     2.295112    2.029270              0.361854    1.590899    5.058090
# ...

# %%
wine.Alcohol.describe()
# Out:
# count    178.000000
# mean      13.000618
# std        0.811827
# min       11.030000
# 25%       12.362500
# 50%       13.050000
# 75%       13.677500
# max       14.830000
# Name: Alcohol, dtype: float64

# %%
flight.airline.unique()
# Out:
# array(['SpiceJet', 'AirAsia', 'Vistara', 'GO_FIRST', 'Indigo',
#        'Air_India'], dtype=object)

# %%
flight.airline.value_counts()
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64

# %%
mean=flight.duration.mean()
flight.duration.map(lambda c: c-mean) #no change on flight
# Out:
# index
# 0        -10.051021
# 1         -9.891021
# 2        -10.051021
# 3         -9.971021
# 4         -9.891021
#             ...
# 300148    -2.141021
# 300149    -1.801021
# 300150     1.608979
# 300151    -2.221021
# 300152    -2.141021
# Name: duration, Length: 300153, dtype: float64

# %%
#Faster
mean=flight.duration.mean()
flight.duration-mean
# Out:
# index
# 0        -10.051021
# 1         -9.891021
# 2        -10.051021
# 3         -9.971021
# 4         -9.891021
#             ...
# 300148    -2.141021
# 300149    -1.801021
# 300150     1.608979
# 300151    -2.221021
# 300152    -2.141021
# Name: duration, Length: 300153, dtype: float64

# %%
#Alternatives :using apply ()
mean=flight.duration.mean()
def duration(row):
    row.duration = row.duration - mean
    return row
flight.apply(duration,axis='columns')
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# index
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class   duration  days_left  price
# index
# ...

# %%
flight.loc[flight.price.idxmax()]
# Out:
# airline              Vistara
# flight                UK-772
# source_city          Kolkata
# departure_time       Morning
# stops                    one
# arrival_time           Night
# destination_city       Delhi
# class               Business
# duration                13.5
# days_left                  3
# price                 123071
# Name: 261377, dtype: object

# %%
flight.airline + '/' + flight.flight
# Out:
# index
# 0         SpiceJet/SG-8709
# 1         SpiceJet/SG-8157
# 2           AirAsia/I5-764
# 3           Vistara/UK-995
# 4           Vistara/UK-963
#                 ...
# 300148      Vistara/UK-822
# 300149      Vistara/UK-826
# 300150      Vistara/UK-832
# 300151      Vistara/UK-828
# 300152      Vistara/UK-822
# Length: 300153, dtype: object

# %%
flight.count()
# Out:
# airline             300153
# flight              300153
# source_city         300153
# departure_time      300153
# stops               300153
# arrival_time        300153
# destination_city    300153
# class               300153
# duration            300153
# days_left           300153
# price               300153
# dtype: int64

# %% [markdown]
# # Grouping & Sorting

# %%
flight.groupby('airline')
flight.groupby('airline').airline.count() #same as flight.airline.value_count()
# Out:
# airline
# AirAsia       16098
# Air_India     80892
# GO_FIRST      23173
# Indigo        43120
# SpiceJet       9011
# Vistara      127859
# Name: airline, dtype: int64

# %%
flight.groupby('airline').price.mean()
# Out:
# airline
# AirAsia       4091.072742
# Air_India    23507.019112
# GO_FIRST      5652.007595
# Indigo        5324.216303
# SpiceJet      6179.278881
# Vistara      30396.536302
# Name: price, dtype: float64

# %%
flight.groupby('airline').apply(lambda df: df.loc[df.price.idxmax()])
# Out:
# /var/folders/ts/g4z7cs9n0w334dflkfv1_wr40000gn/T/ipykernel_52983/1045244163.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   flight.groupby('airline').apply(lambda df: df.loc[df.price.idxmax()])
#              airline  flight source_city departure_time stops arrival_time  \
# airline
# AirAsia      AirAsia  I5-783       Delhi  Early_Morning   one    Afternoon
# Air_India  Air_India  AI-867      Mumbai          Night   one        Night
# GO_FIRST    GO_FIRST  G8-123   Hyderabad  Early_Morning   one        Night
# Indigo        Indigo  6E-634     Kolkata        Morning   one        Night
# SpiceJet    SpiceJet  SG-768   Bangalore      Afternoon   one      Morning
# ...

# %%
flight.groupby('airline').price.agg([len,max,min]) #len is count here
# Out:
# /var/folders/ts/g4z7cs9n0w334dflkfv1_wr40000gn/T/ipykernel_52983/320495825.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   flight.groupby('airline').price.agg([len,max,min]) #len is count here
# /var/folders/ts/g4z7cs9n0w334dflkfv1_wr40000gn/T/ipykernel_52983/320495825.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   flight.groupby('airline').price.agg([len,max,min]) #len is count here
#               len     max   min
# airline
# AirAsia     16098   31917  1105
# Air_India   80892   90970  1526
# GO_FIRST    23173   32803  1105
# Indigo      43120   31952  1105
# SpiceJet     9011   34158  1106
# ...

# %%
flight.groupby('airline').price.agg([len,max,min]).sort_values(by='max',ascending=False)
# Out:
# /var/folders/ts/g4z7cs9n0w334dflkfv1_wr40000gn/T/ipykernel_52983/3606458892.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   flight.groupby('airline').price.agg([len,max,min]).sort_values(by='max',ascending=False)
# /var/folders/ts/g4z7cs9n0w334dflkfv1_wr40000gn/T/ipykernel_52983/3606458892.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   flight.groupby('airline').price.agg([len,max,min]).sort_values(by='max',ascending=False)
#               len     max   min
# airline
# Vistara    127859  123071  1714
# Air_India   80892   90970  1526
# SpiceJet     9011   34158  1106
# GO_FIRST    23173   32803  1105
# ...

# %%
flight.sort_values(by=['airline','flight'],ascending=False)
# Out:
#         airline   flight source_city departure_time stops arrival_time  \
# index
# 43049   Vistara   UK-996      Mumbai        Evening  zero        Night
# 43116   Vistara   UK-996      Mumbai        Evening  zero        Night
# 43241   Vistara   UK-996      Mumbai        Evening  zero        Night
# 43380   Vistara   UK-996      Mumbai        Evening  zero        Night
# 43545   Vistara   UK-996      Mumbai        Evening  zero        Night
# ...         ...      ...         ...            ...   ...          ...
# 192617  AirAsia  I5-1228     Chennai        Morning   one        Night
# 192749  AirAsia  I5-1228     Chennai        Morning   one        Night
# 192887  AirAsia  I5-1228     Chennai        Morning   one        Night
# 193022  AirAsia  I5-1228     Chennai        Morning   one        Night
# 193155  AirAsia  I5-1228     Chennai        Morning   one        Night
#
#        destination_city    class  duration  days_left  price
# index
# ...

# %%
flight.groupby('airline').price.max().sort_index()
# Out:
# airline
# AirAsia       31917
# Air_India     90970
# GO_FIRST      32803
# Indigo        31952
# SpiceJet      34158
# Vistara      123071
# Name: price, dtype: int64

# %%
flight.groupby(['airline','flight']).agg([len]).price.sort_values(by='len',ascending=False)
# Out:
#                    len
# airline  flight
# Vistara  UK-706   3235
#          UK-772   2741
#          UK-720   2650
#          UK-836   2542
#          UK-822   2468
# ...                ...
# Indigo   6E-6474     1
#          6E-865      1
# SpiceJet SG-8339     1
# Indigo   6E-2914     1
#          6E-5003     1
#
# [1561 rows x 1 columns]

# %%
flight.groupby(['airline','flight']).size().sort_values(ascending=False) #use the function size() instead of agg['len']
# Out:
# airline   flight
# Vistara   UK-706     3235
#           UK-772     2741
#           UK-720     2650
#           UK-836     2542
#           UK-822     2468
#                      ...
# Indigo    6E-6474       1
#           6E-865        1
# SpiceJet  SG-8339       1
# Indigo    6E-2914       1
#           6E-5003       1
# Length: 1561, dtype: int64

# %% [markdown]
# # Data Types and Missing Val

# %%
flight.airline.dtype
# Out:
# dtype('O')

# %%
flight.astype('str')
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# index
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class duration days_left  price
# index
# ...

# %%
len(flight[flight.airline.isnull()])
# Out:
# 0

# %%
flight.airline.fillna("Unknown")
# Out:
# index
# 0         SpiceJet
# 1         SpiceJet
# 2          AirAsia
# 3          Vistara
# 4          Vistara
#             ...
# 300148     Vistara
# 300149     Vistara
# 300150     Vistara
# 300151     Vistara
# 300152     Vistara
# Name: airline, Length: 300153, dtype: object

# %%
a = flight.airline.replace("SpiceJet","ThaiJet") #not affecting original
a.value_counts()
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# ThaiJet        9011
# Name: count, dtype: int64

# %% [markdown]
# # Renaming and Combining Cols

# %%
flight.rename(columns={'airline':'company'})
# Out:
#          company   flight source_city departure_time stops   arrival_time  \
# index
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# index
# ...

# %% [markdown]
# ## Concat

# %%
# pd.concat([canadian_youtube, british_youtube])

# %% [markdown]
# ## Join

# %%
# left = canadian_youtube.set_index(['title', 'trending_date'])
# right = british_youtube.set_index(['title', 'trending_date'])

# left.join(right, lsuffix='_CAN', rsuffix='_UK')
